# %% [markdown]
# ## Dataset:
# https://www.kaggle.com/datasets/kumarajarshi/life-expectancy-who

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Importing dataset
lifeExpectancy = pd.read_csv('LifeExpectancyData.csv')

# %%
#View the dataset
lifeExpectancy.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# ...

# %%
#Data types of each column
lifeExpectancy.dtypes
# Out:
# Country                             object
# Year                                 int64
# Status                              object
# Life expectancy                    float64
# Adult Mortality                    float64
# infant deaths                        int64
# Alcohol                            float64
# percentage expenditure             float64
# Hepatitis B                        float64
# Measles                              int64
#  BMI                               float64
# under-five deaths                    int64
# Polio                              float64
# Total expenditure                  float64
# Diphtheria                         float64
#  HIV/AIDS                          float64
# GDP                                float64
# Population                         float64
#  thinness  1-19 years              float64
#  thinness 5-9 years                float64
# Income composition of resources    float64
# Schooling                          float64
# ...

# %% [markdown]
# ### Data Understanding

# %%
#Correlation between the features
lifeExpectancy.select_dtypes(include=['number']).corr() #leaving out columns with object data types
# Out:
#                                      Year  Life expectancy   Adult Mortality  \
# Year                             1.000000          0.170033        -0.079052
# Life expectancy                  0.170033          1.000000        -0.696359
# Adult Mortality                 -0.079052         -0.696359         1.000000
# infant deaths                   -0.037415         -0.196557         0.078756
# Alcohol                         -0.052990          0.404877        -0.195848
# percentage expenditure           0.031400          0.381864        -0.242860
# Hepatitis B                      0.104333          0.256762        -0.162476
# Measles                         -0.082493         -0.157586         0.031176
#  BMI                             0.108974          0.567694        -0.387017
# under-five deaths               -0.042937         -0.222529         0.094146
# Polio                            0.094158          0.465556        -0.274823
# ...

# %% [markdown]
# * From the correlation matrix, Adult Mortality, BMI, Income composition of resources, and Schooling seem to have higher correlations with Life expectancy.

# %%
print(lifeExpectancy.columns)
# Out:
# Index(['Country', 'Year', 'Status', 'Life expectancy ', 'Adult Mortality',
#        'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B',
#        'Measles ', ' BMI ', 'under-five deaths ', 'Polio', 'Total expenditure',
#        'Diphtheria ', ' HIV/AIDS', 'GDP', 'Population',
#        ' thinness  1-19 years', ' thinness 5-9 years',
#        'Income composition of resources', 'Schooling'],
#       dtype='object')

# %%
sns.scatterplot(data = lifeExpectancy, x = " BMI ", y = "Life expectancy ", hue = 'Year')
# Out:
# <Axes: xlabel=' BMI ', ylabel='Life expectancy '>

# %%
sns.scatterplot(data = lifeExpectancy, x = "Income composition of resources", y = "Life expectancy ")
# Out:
# <Axes: xlabel='Income composition of resources', ylabel='Life expectancy '>

# %%
sns.scatterplot(data = lifeExpectancy, x = "Schooling", y = "Life expectancy ", hue = 'Year')
# Out:
# <Axes: xlabel='Schooling', ylabel='Life expectancy '>

# %%
sns.scatterplot(data = lifeExpectancy, x = "Adult Mortality", y = "Life expectancy ", hue = 'Year')
# Out:
# <Axes: xlabel='Adult Mortality', ylabel='Life expectancy '>

# %%
sns.scatterplot(data = lifeExpectancy, x = "Alcohol", y = "Life expectancy ", hue = 'Year')
# Out:
# <Axes: xlabel='Alcohol', ylabel='Life expectancy '>

# %% [markdown]
# ### Data Pre-Processing

# %%
#Removing columns that are not necessary for this project
lifeExpectancy.isna().sum()
# Out:
# Country                              0
# Year                                 0
# Status                               0
# Life expectancy                     10
# Adult Mortality                     10
# infant deaths                        0
# Alcohol                            194
# percentage expenditure               0
# Hepatitis B                        553
# Measles                              0
#  BMI                                34
# under-five deaths                    0
# Polio                               19
# Total expenditure                  226
# Diphtheria                          19
#  HIV/AIDS                            0
# GDP                                448
# Population                         652
#  thinness  1-19 years               34
#  thinness 5-9 years                 34
# Income composition of resources    167
# Schooling                          163
# dtype: int64

# %% [markdown]
# ##### For the first experiment, the targer variable will be Life expectancy and the predictor variables will be BMI and Adult Mortality.
# * We will need to manage the null values in the BMI and Adult Mortality columns

# %%
rows_with_null = lifeExpectancy[lifeExpectancy[' BMI '].isnull() | lifeExpectancy['Adult Mortality'].isnull()]
rows_with_null
# Out:
#                     Country  Year      Status  Life expectancy   \
# 624            Cook Islands  2013  Developing               NaN
# 769                Dominica  2013  Developing               NaN
# 1650       Marshall Islands  2013  Developing               NaN
# 1715                 Monaco  2013  Developing               NaN
# 1812                  Nauru  2013  Developing               NaN
# 1909                   Niue  2013  Developing               NaN
# 1958                  Palau  2013  Developing               NaN
# 2167  Saint Kitts and Nevis  2013  Developing               NaN
# 2216             San Marino  2013  Developing               NaN
# 2409            South Sudan  2015  Developing              57.3
# 2410            South Sudan  2014  Developing              56.6
# 2411            South Sudan  2013  Developing              56.4
# 2412            South Sudan  2012  Developing              56.0
# 2413            South Sudan  2011  Developing              55.4
# ...

# %%
#Drop the rows where Adult Mortality AND Life Expectancy are both null
lifeExpectancy = lifeExpectancy.dropna(subset=['Life expectancy ', 'Adult Mortality'], how='all')

# %%
lifeExpectancy.isna().sum()
# Out:
# Country                              0
# Year                                 0
# Status                               0
# Life expectancy                      0
# Adult Mortality                      0
# infant deaths                        0
# Alcohol                            193
# percentage expenditure               0
# Hepatitis B                        553
# Measles                              0
#  BMI                                32
# under-five deaths                    0
# Polio                               19
# Total expenditure                  226
# Diphtheria                          19
#  HIV/AIDS                            0
# GDP                                443
# Population                         644
#  thinness  1-19 years               32
#  thinness 5-9 years                 32
# Income composition of resources    160
# Schooling                          160
# dtype: int64

# %%
filtered = lifeExpectancy[(lifeExpectancy['Country'].isin(['Sudan', 'South Sudan'])) & (lifeExpectancy[' BMI '].isnull())]
filtered
# Out:
#           Country  Year      Status  Life expectancy   Adult Mortality  \
# 2409  South Sudan  2015  Developing              57.3            332.0
# 2410  South Sudan  2014  Developing              56.6            343.0
# 2411  South Sudan  2013  Developing              56.4            345.0
# 2412  South Sudan  2012  Developing              56.0            347.0
# 2413  South Sudan  2011  Developing              55.4            355.0
# 2414  South Sudan  2010  Developing              55.0            359.0
# 2415  South Sudan  2009  Developing              54.3            369.0
# 2416  South Sudan  2008  Developing              53.6            377.0
# 2417  South Sudan  2007  Developing              53.1            381.0
# 2418  South Sudan  2006  Developing              52.5            383.0
# 2419  South Sudan  2005  Developing              51.9            383.0
# 2420  South Sudan  2004  Developing              51.4            383.0
# ...

# %%
filtered.shape
# Out:
# (32, 22)

# %%
#Drop rows where BMI is null. All these rows are from the coutry of Sudan and South Sudan. Since it is only 2 countries, we can remove it
#for the sake of the experiement.
lifeExpectancy = lifeExpectancy.dropna(subset=[' BMI '])

# %%
lifeExpectancy.isna().sum()
# Out:
# Country                              0
# Year                                 0
# Status                               0
# Life expectancy                      0
# Adult Mortality                      0
# infant deaths                        0
# Alcohol                            176
# percentage expenditure               0
# Hepatitis B                        533
# Measles                              0
#  BMI                                 0
# under-five deaths                    0
# Polio                                8
# Total expenditure                  212
# Diphtheria                           8
#  HIV/AIDS                            0
# GDP                                435
# Population                         644
#  thinness  1-19 years                0
#  thinness 5-9 years                  0
# Income composition of resources    160
# Schooling                          160
# dtype: int64

# %%
rows_with_null = lifeExpectancy[lifeExpectancy['Income composition of resources'].isnull() & lifeExpectancy['Schooling'].isnull()]
rows_with_null
# Out:
#                        Country  Year      Status  Life expectancy   \
# 432              Côte d'Ivoire  2015  Developing              53.3
# 433              Côte d'Ivoire  2014  Developing              52.8
# 434              Côte d'Ivoire  2013  Developing              52.3
# 435              Côte d'Ivoire  2012  Developing              52.0
# 436              Côte d'Ivoire  2011  Developing              51.7
# ...                        ...   ...         ...               ...
# 2805  United States of America  2004   Developed              77.5
# 2806  United States of America  2003   Developed              77.2
# 2807  United States of America  2002   Developed              77.0
# 2808  United States of America  2001   Developed              76.9
# 2809  United States of America  2000   Developed              76.8
#
#       Adult Mortality  infant deaths  Alcohol  percentage expenditure  \
# 432             397.0             57      NaN                     0.0
# ...

# %%
rows_with_null.shape
# Out:
# (160, 22)

# %%
#Drop rows where Income composition of resources AND Schooling is null. We are not predicting life expectancy based on a specific country
#therefore, we will delete these rows.
lifeExpectancy.dropna(subset=['Income composition of resources', 'Schooling'], inplace=True)

# %%
lifeExpectancy.isna().sum()
# Out:
# Country                              0
# Year                                 0
# Status                               0
# Life expectancy                      0
# Adult Mortality                      0
# infant deaths                        0
# Alcohol                            167
# percentage expenditure               0
# Hepatitis B                        489
# Measles                              0
#  BMI                                 0
# under-five deaths                    0
# Polio                                8
# Total expenditure                  172
# Diphtheria                           8
#  HIV/AIDS                            0
# GDP                                278
# Population                         484
#  thinness  1-19 years                0
#  thinness 5-9 years                  0
# Income composition of resources      0
# Schooling                            0
# dtype: int64

# %% [markdown]
# ### Experiment 1 - Linear Regression (Modeling and Evaluation)

# %%
#Dividing data into X and y
X = lifeExpectancy[[' BMI ', 'Adult Mortality']]
y = lifeExpectancy['Life expectancy ']

# %%
#Dividing data into testing and training data
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y,  test_size=0.20, random_state=None)

# %%
#feature scaling using standard scalar
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
#Importing linear regression model from sklearn
from sklearn.linear_model import LinearRegression
lin_reg = LinearRegression()
#training the model
regressor = lin_reg.fit(X_train, y_train)
#making predictions on the test set
y_pred = regressor.predict(X_test)
#evaluating model performance
from sklearn import metrics

print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 4.482684908808548
# Mean Squared Error: 40.387446567984064
# Root Mean Squared Error: 6.355111845434671

# %% [markdown]
# * Predicting a single value:

# %%
newLifeExpectancydf = lifeExpectancy[[' BMI ', 'Adult Mortality']]

# %%
#Data to predict life expectancy
data = np.array([[50,300]])

# %%
scaled = sc.transform(data)
predictedLifeExp = regressor.predict(scaled)

print("Predicted Life expectancy:", predictedLifeExp)
# Out:
# Predicted Life expectancy: [65.67439246]
# /Users/dishaapremnath/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %% [markdown]
# ### Experiment 2 - Random Forest (Modeling and Evaluation)

# %% [markdown]
# * We will use the same features as Experiment 1

# %%
#Importing Random Forest model from sklearn
from sklearn.ensemble import RandomForestRegressor
rf_reg = RandomForestRegressor(random_state=42, n_estimators=200)
#training the model
regressor = rf_reg.fit(X_train, y_train)
#making predicitons on the test set
y_pred = regressor.predict(X_test)
#evaluating the model performance
from sklearn import metrics
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 2.1044578293361056
# Mean Squared Error: 10.152176251787289
# Root Mean Squared Error: 3.1862479896874456

# %% [markdown]
# * Note: The MSE decreased from the first Experiment

# %% [markdown]
# * Predicting a single value:

# %%
scaled = sc.transform(data)
predictedLifeExp = regressor.predict(scaled)

print("Predicted Life expectancy:", predictedLifeExp)
# Out:
# Predicted Life expectancy: [65.1045]
# /Users/dishaapremnath/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %% [markdown]
# ### Experiment 3 - Random Forest (Modeling and Evaluation)
# * We will use the same algorithm as Experiment 2, Random Forest, but we will use the 'Income compositions of resources' and 'Schooling' columns for our predictor variables this time.

# %%
#Dividing data into X and y
X = lifeExpectancy[['Income composition of resources', 'Schooling']]
y = lifeExpectancy['Life expectancy ']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,  test_size=0.20, random_state=None)

# %%
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
rf_reg = RandomForestRegressor(random_state=42, n_estimators=200)
#training the model
regressor = rf_reg.fit(X_train, y_train)
#making predicitons on the test set
y_pred = regressor.predict(X_test)
#evaluating the model performance
from sklearn import metrics
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 3.021850753674934
# Mean Squared Error: 19.2043767259646
# Root Mean Squared Error: 4.382279854820388

# %% [markdown]
# * Predicting a single value:

# %%
#New Data to predict life expectancy
data = np.array([[0.65,12]])

# %%
scaled = sc.transform(data)
predictedLifeExp = regressor.predict(scaled)

print("Predicted Life expectancy:", predictedLifeExp)
# Out:
# Predicted Life expectancy: [72.09675]
# /Users/dishaapremnath/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
